# %% [markdown]
# <a href="https://colab.research.google.com/github/SangeetaChatterjee/WD_Truecue_Hackathon/blob/main/Sustainability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTING REQUIRED PACKAGES

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ESTABLISHING CONNECTION AND READING FILES

from google.colab import drive
drive.mount('/content/drive')

dataset = pd.read_excel('/content/drive/My Drive/Python_Colab/TrueCue_Hackathon/Sustainability_Hackathon_Dataset.xlsx')
dataset.head(5)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#   Country Name  ... World Regions (UN SDG Definition)
# 0        Aruba  ...       Latin America and Caribbean
# 1        Aruba  ...       Latin America and Caribbean
# 2        Aruba  ...       Latin America and Caribbean
# 3        Aruba  ...       Latin America and Caribbean
# 4        Aruba  ...       Latin America and Caribbean
#
# [5 rows x 54 columns]

# %%
dataset.shape
# Out:
# (3287, 54)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 54 columns):
#  #   Column                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                        --------------  -----
#  0   Country Name                                                                                  3287 non-null   object
#  1   Country Code                                                                                  3287 non-null   object
#  2   Year                                                                                          3287 non-null   int64
#  3   Access to electricity (% of population) - EG.ELC.ACCS.ZS                                      3193 non-null   float64
#  4   Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG              2566 non-null   float64
# ...

# %%
dataset.nunique()
# Out:
# Country Name                                                                                     173
# Country Code                                                                                     173
# Year                                                                                              19
# Access to electricity (% of population) - EG.ELC.ACCS.ZS                                        1735
# Adjusted net national income per capita (annual % growth) - NY.ADJ.NNTY.PC.KD.ZG                2566
# Adjusted net savings, excluding particulate emission damage (% of GNI) - NY.ADJ.SVNX.GN.ZS      2628
# Adjusted savings: carbon dioxide damage (% of GNI) - NY.ADJ.DCO2.GN.ZS                          3220
# Adjusted savings: natural resources depletion (% of GNI) - NY.ADJ.DRES.GN.ZS                    2809
# Adjusted savings: net forest depletion (% of GNI) - NY.ADJ.DFOR.GN.ZS                           1049
# ...
